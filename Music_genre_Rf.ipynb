# %%
import numpy as  np
import pandas as  pd
pd.set_option('display.max_columns',None)

# %%
Train_data= pd.read_csv(r'C:\Users\Lenovo\Desktop\dataset\train.csv',header=0,index_col=0)
Test_data= pd.read_csv(r'C:\Users\Lenovo\Desktop\dataset\test.csv',header=0,index_col=0)

# %%
print(Train_data.head())
print(Train_data.shape)
# Out:
#                                         track_name  popularity  acousticness  \
# instance_id
# MSC_83537.0                  Estrellitas y Duendes      49.178      0.970522
# MSC_22044.0                               Al Norte      59.827      1.009380
# MSC_62017.0       Yeah! (feat. Lil Jon & Ludacris)      89.023      0.020041
# MSC_76365.0                          Can’t You See      55.762      0.010284
# MSC_71493.0  Sonata III (G Moll), BWV 1029: Adagio      45.095      0.858769
#
#              danceability  duration_ms    energy  instrumentalness  \
# instance_id
# MSC_83537.0      0.580508   214625.776  0.192107          0.000000
# MSC_22044.0      0.687542   216232.195  0.265942          0.000031
# MSC_62017.0      0.967948   273314.723  0.857411          0.000000
# MSC_76365.0      0.616287   189189.605  0.970513          0.000220
# MSC_71493.0      0.280645   410136.987  0.114732          0.002753
#
#                        key  liveness  loudness voice_gender   mode  \
# ...

# %%
Train_data.describe(include='all')
# Out:
#        track_name    popularity  acousticness  danceability   duration_ms  \
# count       15681  15039.000000  15681.000000  15125.000000  1.558700e+04
# unique      14799           NaN           NaN           NaN           NaN
# top         Smile           NaN           NaN           NaN           NaN
# freq            7           NaN           NaN           NaN           NaN
# mean          NaN     50.822720      0.446922      0.570106  2.480008e+05
# std           NaN     17.679789      0.416981      0.215045  1.568312e+05
# min           NaN      0.000000      0.000002      0.063962 -1.000000e+00
# 25%           NaN     39.017000      0.044521      0.418635  1.860163e+05
# 50%           NaN     54.109000      0.295272      0.586114  2.362127e+05
# 75%           NaN     63.449000      0.929001      0.733073  2.975593e+05
# max           NaN    108.512000      1.094410      1.072089  3.410383e+06
#
#               energy  instrumentalness      key      liveness      loudness  \
# ...

# %%
Train_data=Train_data.replace('?',np.nan)

# %%
Train_data.describe(include='all')
# Out:
#        track_name    popularity  acousticness  danceability   duration_ms  \
# count       15681  15039.000000  15681.000000  15125.000000  1.558700e+04
# unique      14799           NaN           NaN           NaN           NaN
# top         Smile           NaN           NaN           NaN           NaN
# freq            7           NaN           NaN           NaN           NaN
# mean          NaN     50.822720      0.446922      0.570106  2.480008e+05
# std           NaN     17.679789      0.416981      0.215045  1.568312e+05
# min           NaN      0.000000      0.000002      0.063962 -1.000000e+00
# 25%           NaN     39.017000      0.044521      0.418635  1.860163e+05
# 50%           NaN     54.109000      0.295272      0.586114  2.362127e+05
# 75%           NaN     63.449000      0.929001      0.733073  2.975593e+05
# max           NaN    108.512000      1.094410      1.072089  3.410383e+06
#
#               energy  instrumentalness      key      liveness      loudness  \
# ...

# %%
#Preprocessing  Steps
# 1 )Feature importance- Removing 'track name ' from the variables
Train_data=Train_data.drop('track_name',axis=1)

# %%
#%%
Train_data.columns
# Out:
# Index(['popularity', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'voice_gender',
#        'mode', 'speechiness', 'tempo', 'musician_category', 'valence',
#        'music_genre'],
#       dtype='object')

# %%
#%%
#2) Handling Missing values
Train_data.isnull().sum()
# Out:
# popularity            642
# acousticness            0
# danceability          556
# duration_ms            94
# energy                 94
# instrumentalness       95
# key                     0
# liveness                0
# loudness               36
# voice_gender          765
# mode                 1114
# speechiness            26
# tempo                1476
# musician_category    1360
# valence               677
# music_genre             0
# dtype: int64

# %%
print(Train_data.shape)
print(Train_data.dtypes)
# Out:
# (15681, 16)
# popularity           float64
# acousticness         float64
# danceability         float64
# duration_ms          float64
# energy               float64
# instrumentalness     float64
# key                   object
# liveness             float64
# loudness             float64
# voice_gender          object
# mode                  object
# speechiness          float64
# tempo                 object
# musician_category     object
# valence              float64
# music_genre           object
# dtype: object

# %%
Train_data['tempo']=Train_data['tempo'].astype(float,errors='raise')

# %%
Train_data.dtypes
# Out:
# popularity           float64
# acousticness         float64
# danceability         float64
# duration_ms          float64
# energy               float64
# instrumentalness     float64
# key                   object
# liveness             float64
# loudness             float64
# voice_gender          object
# mode                  object
# speechiness          float64
# tempo                float64
# musician_category     object
# valence              float64
# music_genre           object
# dtype: object

# %%
#Replacing missing values with mean value  in continuous variables.
for i in['popularity','danceability','duration_ms','energy','instrumentalness','loudness','speechiness','tempo','valence']:
    Train_data[i].fillna(Train_data[i].mean(),inplace= True)

# %%
 Train_data.isnull().sum()
# Out:
# popularity              0
# acousticness            0
# danceability            0
# duration_ms             0
# energy                  0
# instrumentalness        0
# key                     0
# liveness                0
# loudness                0
# voice_gender          765
# mode                 1114
# speechiness             0
# tempo                   0
# musician_category    1360
# valence                 0
# music_genre             0
# dtype: int64

# %%
 #Replacing missing values with mode value  in categorical variables.
 for i in ['voice_gender','mode','musician_category']:
     Train_data[i].fillna(Train_data[i].mode()[0],inplace= True)

# %%
 Train_data.isnull().sum()
# Out:
# popularity           0
# acousticness         0
# danceability         0
# duration_ms          0
# energy               0
# instrumentalness     0
# key                  0
# liveness             0
# loudness             0
# voice_gender         0
# mode                 0
# speechiness          0
# tempo                0
# musician_category    0
# valence              0
# music_genre          0
# dtype: int64

# %%
 Train_data.describe(include='all')
# Out:
#           popularity  acousticness  danceability   duration_ms        energy  \
# count   15681.000000  15681.000000  15681.000000  1.568100e+04  15681.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       50.822720      0.446922      0.570106  2.480008e+05      0.426977
# std        17.314066      0.416981      0.211198  1.563604e+05      0.512602
# min         0.000000      0.000002      0.063962 -1.000000e+00     -1.000000
# 25%        39.414000      0.044521      0.425694  1.864208e+05      0.159934
# 50%        53.135000      0.295272      0.576149  2.368236e+05      0.557718
# 75%        63.064000      0.929001      0.726697  2.969948e+05      0.790423
# max       108.512000      1.094410      1.072089  3.410383e+06      1.094853
#
# ...

# %%
 #3)Converting categorical data into numerical data
 Train_data.music_genre .value_counts()
# Out:
# Classical     3990
# Rock          3879
# Rap           3207
# Jazz          2850
# Country        683
# Electronic     614
# Hip-Hop        458
# Name: music_genre, dtype: int64

# %%
Train_data.music_genre=Train_data.music_genre.map({'Classical':1,'Rock':2,'Rap':3,'Jazz':4,'Country':5,'Electronic':6,'Hip-Hop':7})

# %%
 Train_data.music_genre.value_counts()
# Out:
# 1    3990
# 2    3879
# 3    3207
# 4    2850
# 5     683
# 6     614
# 7     458
# Name: music_genre, dtype: int64

# %%
colname=['key','voice_gender','mode','musician_category']
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
for i in colname:
    Train_data[i]=le.fit_transform(Train_data[i])

# %%
Train_data.head()
# Out:
#              popularity  acousticness  danceability  duration_ms    energy  \
# instance_id
# MSC_83537.0      49.178      0.970522      0.580508   214625.776  0.192107
# MSC_22044.0      59.827      1.009380      0.687542   216232.195  0.265942
# MSC_62017.0      89.023      0.020041      0.967948   273314.723  0.857411
# MSC_76365.0      55.762      0.010284      0.616287   189189.605  0.970513
# MSC_71493.0      45.095      0.858769      0.280645   410136.987  0.114732
#
#              instrumentalness  key  liveness  loudness  voice_gender  mode  \
# instance_id
# MSC_83537.0          0.000000    7  0.147134   -14.140             1     0
# MSC_22044.0          0.000031    0  0.174655   -13.716             2     0
# MSC_62017.0          0.000000    5  0.042030    -4.995             1     0
# MSC_76365.0          0.000220    5  0.124637    -4.262             0     0
# MSC_71493.0          0.002753    9  0.134782   -26.922             1     1
#
# ...

# %%
 #Preprocessing  Testing data
print(Test_data.head())
print(Test_data.shape)
# Out:
#                                               track_name  popularity  \
# instance_id
# MSC_70753.0  Bard, a Man of Lake-town - Extended Version      26.101
# MSC_24064.0                                    New Kings      66.325
# MSC_22731.0                                Silver Lining      71.871
# MSC_32095.0                     A Tale That Wasn't Right      56.151
# MSC_24198.0                                    Get Ready      43.687
#
#              acousticness  danceability  duration_ms    energy  \
# instance_id
# MSC_70753.0      0.823765      0.115490   211462.287  0.125325
# MSC_24064.0      0.015441      0.592838   249151.238  0.870798
# MSC_22731.0      0.001006      0.510340   215693.240  0.683077
# MSC_32095.0      0.315650      0.338336   307056.179  0.608904
# MSC_24198.0      0.038336      0.773904   352802.872  0.955500
#
#              instrumentalness            key  liveness  loudness voice_gender  \
# instance_id
# ...

# %%
Test_data=Test_data.replace('?',np.nan)

# %%
Test_data.describe(include='all')
# Out:
#        track_name   popularity  acousticness  danceability   duration_ms  \
# count        3921  3755.000000   3921.000000   3782.000000  3.900000e+03
# unique       3850          NaN           NaN           NaN           NaN
# top        Psycho          NaN           NaN           NaN           NaN
# freq            3          NaN           NaN           NaN           NaN
# mean          NaN    50.581611      0.445990      0.569210  2.495970e+05
# std           NaN    18.354740      0.417772      0.215494  1.556545e+05
# min           NaN     0.000000      0.000002      0.065425 -1.000000e+00
# 25%           NaN    38.762500      0.041812      0.411890  1.873481e+05
# 50%           NaN    54.310000      0.282626      0.585554  2.387812e+05
# 75%           NaN    63.583500      0.926555      0.737308  3.006447e+05
# max           NaN   100.350000      1.093955      1.056572  2.096423e+06
#
#              energy  instrumentalness      key     liveness     loudness  \
# ...

# %%
#Preprocessing  Steps
# 1 )Feature importance- Removing 'track name ' from the variables
Test_data=Test_data.drop('track_name',axis=1)

# %%
Test_data.columns
# Out:
# Index(['popularity', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'voice_gender',
#        'mode', 'speechiness', 'tempo', 'musician_category', 'valence'],
#       dtype='object')

# %%
#2) Handling Missing values
Test_data.isnull().sum()
# Out:
# popularity           166
# acousticness           0
# danceability         139
# duration_ms           21
# energy                33
# instrumentalness      23
# key                    0
# liveness               0
# loudness               3
# voice_gender         186
# mode                 259
# speechiness            7
# tempo                391
# musician_category    312
# valence              191
# dtype: int64

# %%
print(Test_data.shape)
print(Test_data.dtypes)
# Out:
# (3921, 15)
# popularity           float64
# acousticness         float64
# danceability         float64
# duration_ms          float64
# energy               float64
# instrumentalness     float64
# key                   object
# liveness             float64
# loudness             float64
# voice_gender          object
# mode                  object
# speechiness          float64
# tempo                 object
# musician_category     object
# valence              float64
# dtype: object

# %%
Test_data['tempo']=Test_data['tempo'].astype(float,errors='raise')

# %%
Test_data.dtypes
# Out:
# popularity           float64
# acousticness         float64
# danceability         float64
# duration_ms          float64
# energy               float64
# instrumentalness     float64
# key                   object
# liveness             float64
# loudness             float64
# voice_gender          object
# mode                  object
# speechiness          float64
# tempo                float64
# musician_category     object
# valence              float64
# dtype: object

# %%
#Replacing missing values with mean value  in continuous variables.
for i in['popularity','danceability','duration_ms','energy','instrumentalness','loudness','speechiness','tempo','valence']:
    Test_data[i].fillna(Test_data[i].mean(),inplace= True)

# %%
Test_data.isnull().sum()
# Out:
# popularity             0
# acousticness           0
# danceability           0
# duration_ms            0
# energy                 0
# instrumentalness       0
# key                    0
# liveness               0
# loudness               0
# voice_gender         186
# mode                 259
# speechiness            0
# tempo                  0
# musician_category    312
# valence                0
# dtype: int64

# %%
 #Replacing missing values with mode value  in categorical variables.
 for i in ['voice_gender','mode','musician_category']:
     Test_data[i].fillna(Test_data[i].mode()[0],inplace= True)

# %%
Test_data.isnull().sum()
# Out:
# popularity           0
# acousticness         0
# danceability         0
# duration_ms          0
# energy               0
# instrumentalness     0
# key                  0
# liveness             0
# loudness             0
# voice_gender         0
# mode                 0
# speechiness          0
# tempo                0
# musician_category    0
# valence              0
# dtype: int64

# %%
 Test_data.describe(include='all')
# Out:
#          popularity  acousticness  danceability   duration_ms       energy  \
# count   3921.000000   3921.000000   3921.000000  3.921000e+03  3921.000000
# unique          NaN           NaN           NaN           NaN          NaN
# top             NaN           NaN           NaN           NaN          NaN
# freq            NaN           NaN           NaN           NaN          NaN
# mean      50.581611      0.445990      0.569210  2.495970e+05     0.429010
# std       17.961902      0.417772      0.211639  1.552370e+05     0.508459
# min        0.000000      0.000002      0.065425 -1.000000e+00    -1.000000
# 25%       39.292000      0.041812      0.420225  1.877879e+05     0.173747
# 50%       53.157000      0.282626      0.574001  2.394281e+05     0.558540
# 75%       63.240000      0.926555      0.732661  2.998095e+05     0.788563
# max      100.350000      1.093955      1.056572  2.096423e+06     1.092213
#
# ...

# %%
#3)Converting categorical data into numerical data
colname=['key','voice_gender','mode','musician_category']
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
for i in colname:
    Test_data[i]=le.fit_transform(Test_data[i])

# %%
#4)Training and Testing data 
  #Training data
X_train=Train_data.values[:,0:-1]
Y_train=Train_data.values[:,-1]
Y_train=Y_train.astype(int)

# %%
Y_train.shape
# Out:
# (15681,)

# %%
#Testing data
X_test=Test_data.values[:,:]

# %%
X_test.shape
# Out:
# (3921, 15)

# %%
#4)Scaling the Xdata for Training and Testing
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train)
X_train = scaler.transform(X_train)

X_test = scaler.transform(X_test)

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Balancing data set
from imblearn.over_sampling import SMOTE
smote=SMOTE()

# %%
X_train_smote,Y_train_smote=smote.fit_sample(X_train.astype(float),Y_train)

# %%
from collections import Counter

# %%
print('before smote',Counter(Y_train))
print('after smaote',Counter(Y_train_smote))

# %%
#Using KNN method
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
model_KNN=KNeighborsClassifier(n_neighbors=10,metric='manhattan')
model_KNN.fit(X_train_smote,Y_train_smote)
Y_pred=model_KNN.predict(X_test)

# %%
model_KNN.score(X_train_smote,Y_train_smote)
# Out:
# 0.8140708915145005

# %%
# Using SVM
from sklearn.svm import SVC
svc_model=SVC(kernel='rbf',C=600.0,gamma=0.1)
svc_model.fit(X_train_smote, Y_train_smote)
Y_pred=svc_model.predict(X_test)

# %%
svc_model.score(X_train_smote,Y_train_smote)
# Out:
# 0.9972789115646259

# %%
from sklearn.ensemble import RandomForestClassifier

model_RandomForest=RandomForestClassifier(n_estimators=100, random_state=10)
model_RandomForest.fit(X_train_smote,Y_train_smote)

Y_pred=model_RandomForest.predict(X_test)

# %%
model_RandomForest.score(X_train_smote,Y_train_smote)
# Out:
# 1.0

# %%
Test_data_1=pd.read_csv(r'C:\Users\Lenovo\Desktop\dataset\test.csv',header=0,index_col=0)
Test_data_1["music_genre"]=Y_pred
Test_data_1.head()
# Out:
#                                               track_name  popularity  \
# instance_id
# MSC_70753.0  Bard, a Man of Lake-town - Extended Version      26.101
# MSC_24064.0                                    New Kings      66.325
# MSC_22731.0                                Silver Lining      71.871
# MSC_32095.0                     A Tale That Wasn't Right      56.151
# MSC_24198.0                                    Get Ready      43.687
#
#              acousticness  danceability  duration_ms    energy  \
# instance_id
# MSC_70753.0      0.823765      0.115490   211462.287  0.125325
# MSC_24064.0      0.015441      0.592838   249151.238  0.870798
# MSC_22731.0      0.001006      0.510340   215693.240  0.683077
# MSC_32095.0      0.315650      0.338336   307056.179  0.608904
# MSC_24198.0      0.038336      0.773904   352802.872  0.955500
#
#              instrumentalness            key  liveness  loudness voice_gender  \
# instance_id
# ...

# %%
Test_data_1.columns
# Out:
# Index(['track_name', 'popularity', 'acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'voice_gender', 'mode', 'speechiness', 'tempo',
#        'musician_category', 'valence', 'music_genre'],
#       dtype='object')

# %%
Test_data_1= Test_data_1.drop(['track_name', 'popularity', 'acousticness',
       'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key',
       'liveness', 'loudness', 'voice_gender', 'mode', 'speechiness', 'tempo',
       'musician_category', 'valence'],axis=1)

# %%
Test_data_1.head()
# Out:
#              music_genre
# instance_id
# MSC_70753.0            1
# MSC_24064.0            2
# MSC_22731.0            2
# MSC_32095.0            2
# MSC_24198.0            4

# %%
Test_data_1=Test_data_1.music_genre.map({1:'Classical',2:'Rock',3:'Rap',4:'Jazz',5:'Country',6:'Electronic',7:'Hip-Hop'})

# %%
Test_data_1.value_counts()
# Out:
# Rock          996
# Classical     989
# Rap           787
# Jazz          678
# Country       219
# Electronic    183
# Hip-Hop        69
# Name: music_genre, dtype: int64

# %%
Test_data_1.to_csv(r'C:\Users\Lenovo\Desktop\dataset\music_genere_RF_NEW.csv')
